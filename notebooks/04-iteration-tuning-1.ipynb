# %% [markdown]
# # Iterating, Tuning Hyper-Parameters and Testing Advanced Features

# %% [markdown]
# ## Key Revisions to the Strategic Framework

# %% [markdown]
# 1. Feature Engineering Becomes a Cycle of Creation and Pruning
#
# 2. Robust, API-Ready Validation is Non-Negotiable.
#
# 3. Targeted, Metric-Driven Hyperparameter Tuning.
#
# 4. Modular, Interpretable Code.

# %% [markdown]
# ## Setup and Load Data

# %%
#### TEMPORARY
import sys
sys.path.append('/home/bac/code/kaggle/kaggle-cmi-detect-behavior/')

# %%
import pandas as pd
import numpy as np
import os
import catboost as cat
from sklearn.model_selection import StratifiedGroupKFold
from sklearn.metrics import f1_score, make_scorer
from sklearn.inspection import permutation_importance
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)
sns.set_style('whitegrid')

# --- Pathing and Experiment Tracking Setup ---
from src.tracking import ExperimentTracker
from src.config import DATA_PATH, PROJECT_PATH, USE_WANDB, WANDB_PROJECT, WANDB_ENTITY

tracker = ExperimentTracker(
    project_path=os.path.expanduser(PROJECT_PATH),
    use_wandb=USE_WANDB,
    wandb_project_name=WANDB_PROJECT,
    wandb_entity=WANDB_ENTITY
)

SEED = 42

# %%
def display_all(df):
    with pd.option_context("display.max_rows", 500, "display.max_columns", 1000):
        display(df)

# %%
# Load the raw data and create helper maps
train_sensor = pd.read_csv(os.path.join(os.path.expanduser(DATA_PATH), 'train.csv'))
train_demos = pd.read_csv(os.path.join(os.path.expanduser(DATA_PATH), 'train_demographics.csv'))
train_df = pd.merge(train_sensor, train_demos, on='subject', how='left')
metadata = train_df[['gesture', 'sequence_type']].drop_duplicates()
gesture_to_seq_type_map = metadata.set_index('gesture')['sequence_type'].to_dict()
gesture_map = {label: i for i, label in enumerate(metadata['gesture'].unique())}
inv_gesture_map = {i: label for label, i in gesture_map.items()}

# %% [markdown]
# ## Pipeline Components

# %% [markdown]
# Major components which have been used to train the model baseline thusfar will be encapsulated in modular code.
#
# 1. Wave 4 feature generation (minus sex and handedness for now since these two features cause a drop in model CV performance - but notably reduce std. deviation)
# 2. Competition metric
# 3. Model Training

# %%
def create_wave4_features(df):
    """
    Creates Wave-4 features: Adds demographic features to Wave 3a-PCA
    feature set.
    """
    df_feat = df.copy()
    
    # Generate Wave3a-PCA feature set
    df_feat['acc_mag'] = np.sqrt(df_feat['acc_x']**2 + df_feat['acc_y']**2 + df_feat['acc_z']**2)
    df_feat['rot_mag'] = np.sqrt(df_feat['rot_w']**2 + df_feat['rot_x']**2 + df_feat['rot_y']**2 + df_feat['rot_z']**2)
    df_feat['jerk'] = df_feat.groupby('sequence_id')['acc_mag'].diff().fillna(0)
    for i in range(1, 5): 
        df_feat[f'thm_grad_{i}_{i+1}'] = df_feat[f'thm_{i}'] - df_feat[f'thm_{i+1}']
    
    # PCA on ToF
    tof_cols = [f'tof_{s}_v{p}' for s in range(1, 6) for p in range(64)]
    tof_data = df_feat[tof_cols].replace(-1, np.nan)
    df_feat['tof_invalid_pct'] = tof_data.isna().mean(axis=1)
    pca = PCA(n_components=10, random_state=SEED)
    tof_pca_features = pca.fit_transform(tof_data.fillna(0))
    for i in range(10): 
        df_feat[f'tof_pca_{i}'] = tof_pca_features[:, i]
    
    # Aggregations
    base_cols_to_agg = [col for col in df.columns if 'acc_' in col or 'rot_' in col or 'thm_' in col]
    derived_cols_to_agg = ['acc_mag', 'rot_mag', 'jerk'] + [f'thm_grad_{i}_{i+1}' for i in range(1, 5)]
    tof_derived_cols_to_agg = ['tof_invalid_pct'] + [f'tof_pca_{i}' for i in range(10)]
    aggs = {}
    for col in base_cols_to_agg + derived_cols_to_agg + tof_derived_cols_to_agg:
        aggs[col] = ['mean', 'std', 'min', 'max', 'skew']

    phase_agg_df = df_feat.groupby(['sequence_id', 'phase']).agg(aggs)
    phase_agg_df.columns = ['_'.join(col).strip() for col in phase_agg_df.columns.values]
    
    phase_agg_df_unstacked = phase_agg_df.unstack(level='phase') # Allow Catboost to handle NaNs as possible phase signals
    phase_agg_df_unstacked.columns = ['_'.join(col).strip() for col in phase_agg_df_unstacked.columns.values]
    
    meta_df = df.groupby('sequence_id').first()
    final_df = pd.concat([meta_df[['subject', 'gesture'] + list(train_demos.columns[1:])], phase_agg_df_unstacked], axis=1).reset_index()
    
    # Create interaction features
    key_sensor_features = [
        'acc_mag_mean_Gesture', 'acc_mag_std_Gesture', 'jerk_mean_Gesture',
        'jerk_std_Gesture', 'tof_pca_0_mean_Gesture', 'tof_invalid_pct_mean_Gesture' # fix for tofl
    ]
    demographic_features = ['age', 'height_cm', 'shoulder_to_wrist_cm'] # For interaction by division and multiplication
    
    for sensor_feat in key_sensor_features:
        for demo_feat in demographic_features:
            if sensor_feat in final_df.columns and demo_feat in final_df.columns:
                # Interaction by division (normalizing sensor reading by demographic)
                final_df[f'{sensor_feat}_div_{demo_feat}'] = final_df[sensor_feat] / (final_df[demo_feat] + 1e-6)
                # Ineraction by multiplication
                final_df[f'{sensor_feat}_mul_{demo_feat}'] = final_df[sensor_feat] * final_df[demo_feat]
    
    #final_df.drop(columns='subject', inplace=True)
    final_df['gesture_encoded'] = final_df['gesture'].map(gesture_map)
    
    print(f"Feature engineering complete. Shape of features: {final_df.shape}")
    return final_df

# %%
# Modified version to handle permutation importance calculations

# --- The Final, Robust Scorer Factory ---
def create_competition_scorer(inv_map, seq_type_map):
    """
    This factory function creates a robust, self-contained scorer
    that can handle both predicted probabilities (2D) and predicted labels (1D).
    """
    
    def competition_f1_score_internal(y_true_encoded, y_pred, **kwargs):
        """
        The actual scoring logic. It checks the dimension of y_pred to
        determine if it needs to perform an argmax operation.
        """
        # --- ROBUSTNESS FIX ---
        if y_pred.ndim == 2:
            # Input is probabilities, find the most likely class
            y_pred_encoded = np.argmax(y_pred, axis=1)
        else:
            # Input is already encoded labels
            y_pred_encoded = y_pred

        # Map integer-encoded labels back to their string representations
        y_true_str = pd.Series(y_true_encoded).map(inv_map)
        y_pred_str = pd.Series(y_pred_encoded).map(inv_map)
        
        # --- The rest of the scoring logic is the same ---
        y_true_binary = y_true_str.map(seq_type_map)
        y_pred_binary = y_pred_str.map(seq_type_map)
        binary_f1 = f1_score(y_true_binary, y_pred_binary, pos_label='Target', average='binary', zero_division=0)

        def collapse_non_target(gesture):
            return 'non_target' if seq_type_map.get(gesture) == 'Non-Target' else gesture
            
        y_true_collapsed = y_true_str.apply(collapse_non_target)
        y_pred_collapsed = y_pred_str.apply(collapse_non_target)
        macro_f1 = f1_score(y_true_collapsed, y_pred_collapsed, average='macro', zero_division=0)
        
        return (binary_f1 + macro_f1) / 2

    return competition_f1_score_internal

# %%
def get_trained_model(X_train, y_train, X_val, y_val, params): # 
    """Trains a CatBoost model and returns the trained object."""
    model = cat.CatBoostClassifier(**params)
    model.fit(X_train, y_train, eval_set=[(X_val, y_val)], early_stopping_rounds=100)
    return model


def plot_feature_importance(model, feature_names, top_n=200):
    """Plots feature importance from a trained CatBoost model"""
    imp_df = pd.DataFrame({
        'feature': feature_names,
        'importance': model.get_feature_importance()
    }).sort_values('importance', ascending=False).head(top_n)
    
    plt.figure(figsize=(8, top_n / 4))
    sns.barplot(x='importance', y='feature', data=imp_df)
    plt.title(f'Top {top_n} Features (CatBoost Built-in Importance)')
    plt.tight_layout()
    plt.show()
    return imp_df

def calculate_permutation_importance(model, X_val, y_val, scorer, top_n=200):
    """Calculates and plots permutation importance."""
    print("Calculating Permutation Importance...")
    
    # We will now use n_jobs=1 by default to guarantee stability.
    result = permutation_importance(
        model, X_val, y_val, n_repeats=5, random_state=SEED, n_jobs=1, scoring=scorer
    )
    
    perm_importance_df = pd.DataFrame({
        'feature': X_val.columns,
        'importance_mean': result.importances_mean,
        'importance_std': result.importances_std,
    }).sort_values('importance_mean', ascending=False)
    
    positive_importance_df = perm_importance_df[perm_importance_df['importance_mean'] > 0].head(top_n)

    if positive_importance_df.empty:
        print("\n!!! No features with positive permutation importance were found.")
        return perm_importance_df

    print("\nTop 10 Permutation Importances:\n", positive_importance_df.head(10))
    
    plt.figure(figsize=(8, max(10, top_n / 4)))
    plt.barh(
        positive_importance_df['feature'],
        positive_importance_df['importance_mean'],
        xerr=positive_importance_df['importance_std'],
        align='center'
    )
    plt.title(f'Top {top_n} Features with Positive Permutation Importance')
    plt.gca().invert_yaxis()
    plt.tight_layout()
    plt.show()
    
    return perm_importance_df

# %%
features_df = create_wave4_features(train_df)
# Out:
# Feature engineering complete. Shape of features: (8151, 347)

# %%
display_all(features_df.head(3))
# Out:
#   sequence_id      subject                   gesture  adult_child  age  sex  \
# 0  SEQ_000007  SUBJ_059520        Cheek - pinch skin            0   12    1
# 1  SEQ_000008  SUBJ_020948  Forehead - pull hairline            1   24    1
# 2  SEQ_000013  SUBJ_040282        Cheek - pinch skin            0   12    1
#
#    handedness  height_cm  shoulder_to_wrist_cm  elbow_to_wrist_cm  \
# 0           1      163.0                    52               24.0
# 1           1      173.0                    49               26.0
# 2           1      157.0                    44               26.0
#
#    acc_x_mean_Gesture  acc_x_mean_Transition  acc_x_std_Gesture  \
# 0            6.875854               5.227969           0.779424
# 1            3.449929               3.353906           0.736728
# 2           -7.591276              -6.364640           1.143683
#
#    acc_x_std_Transition  acc_x_min_Gesture  acc_x_min_Transition  \
# 0              1.334370           5.492188              3.613281
# 1              1.346681           1.734375              1.886719
# 2              1.162073          -9.250000             -7.714844
#
#    acc_x_max_Gesture  acc_x_max_Transition  acc_x_skew_Gesture  \
# 0           9.015625              7.292969            0.671795
# 1           4.949219              5.906250           -0.292417
# 2          -5.226562             -3.347656            0.395099
#
#    acc_x_skew_Transition  acc_y_mean_Gesture  acc_y_mean_Transition  \
# 0               0.119323            5.640137               1.708125
# 1               0.278393            7.261364               3.472433
# 2               1.138648            3.751562               0.513077
#
#    acc_y_std_Gesture  acc_y_std_Transition  acc_y_min_Gesture  \
# 0           0.582177              3.493182           4.683594
# 1           0.824113              3.638059           4.718750
# 2           0.571292              2.984959           2.656250
#
#    acc_y_min_Transition  acc_y_max_Gesture  acc_y_max_Transition  \
# 0             -2.019531           6.519531              6.214844
# 1             -0.222656           8.667969              7.976562
# 2             -3.273438           4.683594              3.957031
#
#    acc_y_skew_Gesture  acc_y_skew_Transition  acc_z_mean_Gesture  \
# 0           -0.177613               0.188431            4.259521
# 1           -0.761132               0.295310            5.647609
# 2            0.011108              -0.231933           -5.493620
#
#    acc_z_mean_Transition  acc_z_std_Gesture  acc_z_std_Transition  \
# 0               7.265156           1.247767              2.335664
# 1               7.462277           1.740919              2.752709
# 2              -6.818444           0.968642              1.382213
#
#    acc_z_min_Gesture  acc_z_min_Transition  acc_z_max_Gesture  \
# 0           1.093750              3.125000           6.875000
# 1           1.722656              3.175781           9.000000
# 2          -6.808594            -10.945312          -3.515625
#
#    acc_z_max_Transition  acc_z_skew_Gesture  acc_z_skew_Transition  \
# 0              9.792969            0.123765              -0.430736
# 1             11.074219           -0.225780              -0.278592
# 2             -5.277344            0.279689              -1.467629
#
#    rot_w_mean_Gesture  rot_w_mean_Transition  rot_w_std_Gesture  \
# 0            0.230537               0.305862           0.043031
# 1            0.229918               0.256294           0.026109
# 2            0.474384               0.285024           0.044857
#
#    rot_w_std_Transition  rot_w_min_Gesture  rot_w_min_Transition  \
# 0              0.073551           0.170898              0.134399
# 1              0.084777           0.185181              0.157593
# 2              0.172503           0.404968              0.061157
#
#    rot_w_max_Gesture  rot_w_max_Transition  rot_w_skew_Gesture  \
# 0           0.327942              0.379272            0.684978
# 1           0.305420              0.341980            0.725468
# 2           0.540771              0.480835           -0.014976
#
#    rot_w_skew_Transition  rot_x_mean_Gesture  rot_x_mean_Transition  \
# 0              -0.869169           -0.302607              -0.252927
# 1              -0.163603           -0.091453              -0.141370
# 2              -0.239875            0.254718               0.453091
#
#    rot_x_std_Gesture  rot_x_std_Transition  rot_x_min_Gesture  \
# 0           0.058485              0.040159          -0.442871
# 1           0.028465              0.052901          -0.160339
# 2           0.025604              0.232688           0.221008
#
#    rot_x_min_Transition  rot_x_max_Gesture  rot_x_max_Transition  \
# 0             -0.355164          -0.212952             -0.204163
# 1             -0.263306          -0.050537             -0.079468
# 2              0.140991           0.304016              0.726501
#
#    rot_x_skew_Gesture  rot_x_skew_Transition  rot_y_mean_Gesture  \
# 0           -0.594216              -0.946573           -0.431194
# 1           -0.668575              -0.427363           -0.432821
# 2            0.539700              -0.009959            0.836882
#
#    rot_y_mean_Transition  rot_y_std_Gesture  rot_y_std_Transition  \
# 0              -0.203823           0.033207              0.199606
# 1              -0.257005           0.079182              0.223424
# 2               0.753060           0.022810              0.119621
#
#    rot_y_min_Gesture  rot_y_min_Transition  rot_y_max_Gesture  \
# 0          -0.478027             -0.447327          -0.364746
# 1          -0.495483             -0.508606          -0.093811
# 2           0.797424              0.580505           0.875366
#
#    rot_y_max_Transition  rot_y_skew_Gesture  rot_y_skew_Transition  \
# 0              0.005066            0.533235              -0.068043
# 1             -0.031555            3.356636              -0.156264
# 2              0.881653           -0.071165              -0.405698
#
#    rot_z_mean_Gesture  rot_z_mean_Transition  rot_z_std_Gesture  \
# 0           -0.814034              -0.868665           0.023412
# 1           -0.862236              -0.887312           0.021701
# 2            0.078009              -0.095658           0.023455
#
#    rot_z_std_Transition  rot_z_min_Gesture  rot_z_min_Transition  \
# 0              0.037632          -0.854187             -0.914856
# 1              0.053133          -0.933899             -0.937805
# 2              0.212688           0.043457             -0.406799
#
#    rot_z_max_Gesture  rot_z_max_Transition  rot_z_skew_Gesture  \
# 0          -0.757935             -0.809753            0.157845
# 1          -0.837036             -0.814697           -2.201159
# 2           0.105957              0.129761           -0.259239
#
#    rot_z_skew_Transition  thm_1_mean_Gesture  thm_1_mean_Transition  \
# 0               0.328752           28.572991              28.704366
# 1               0.211861           32.273003              28.758968
# 2              -0.384956           24.311727              24.797481
#
#    thm_1_std_Gesture  thm_1_std_Transition  thm_1_min_Gesture  \
# 0           0.381308              0.769848          27.782368
# 1           1.175071              2.644869          26.886362
# 2           0.090862              0.572397          24.181389
#
#    thm_1_min_Transition  thm_1_max_Gesture  thm_1_max_Transition  \
# 0             27.696510          29.215113             30.543730
# 1             25.985313          32.870808             32.105263
# 2             24.223915          24.484457             25.634346
#
#    thm_1_skew_Gesture  thm_1_skew_Transition  thm_2_mean_Gesture  \
# 0           -0.425742               0.732803           30.761249
# 1           -3.955113               0.294443           32.016294
# 2            0.203860               0.289273           24.065670
#
#    thm_2_mean_Transition  thm_2_std_Gesture  thm_2_std_Transition  \
# 0              28.049465           0.485551              3.299713
# 1              27.473724           1.988673              3.963966
# 2              24.760440           0.061293              0.787152
#
#    thm_2_min_Gesture  thm_2_min_Transition  thm_2_max_Gesture  \
# 0          30.041212             24.558798          31.663404
# 1          24.039984             23.907709          33.100945
# 2          23.933413             24.035677          24.194889
#
#    thm_2_max_Transition  thm_2_skew_Gesture  thm_2_skew_Transition  \
# 0             32.010178            0.291830               0.058794
# 1             32.403992           -3.533768               0.322120
# 2             26.175961            0.211255               0.622450
#
#    thm_3_mean_Gesture  thm_3_mean_Transition  thm_3_std_Gesture  \
# 0           29.116922              27.885000           0.197033
# 1           30.335959              28.089808           1.261277
# 2           24.744966              25.084761           0.207938
#
#    thm_3_std_Transition  thm_3_min_Gesture  thm_3_min_Transition  \
# 0              1.664297          28.557234             25.907490
# 1              3.822748          25.774496             24.414917
# 2              0.283411          24.406981             24.587378
#
#    thm_3_max_Gesture  thm_3_max_Transition  thm_3_skew_Gesture  \
# 0          29.396484             30.090014           -1.083624
# 1          31.516409             32.316135           -2.445173
# 2          25.136721             25.512794            0.051444
#
#    thm_3_skew_Transition  thm_4_mean_Gesture  thm_4_mean_Transition  \
# 0              -0.106085           29.078639              29.305039
# 1               0.154153           31.252343              29.793223
# 2               0.049188           24.664993              25.277597
#
#    thm_4_std_Gesture  thm_4_std_Transition  thm_4_min_Gesture  \
# 0           0.148042              0.349623          28.819799
# 1           0.365182              0.830051          29.622156
# 2           0.150427              0.723736          24.419798
#
#    thm_4_min_Transition  thm_4_max_Gesture  thm_4_max_Transition  \
# 0             28.592863          29.346125             29.761480
# 1             28.755495          31.613327             30.865301
# 2             24.516800          24.930002             26.452927
#
#    thm_4_skew_Gesture  thm_4_skew_Transition  thm_5_mean_Gesture  \
# 0            0.169882              -0.345342           28.359300
# 1           -3.210709               0.273863           26.816013
# 2            0.328370               0.355179           24.628350
#
#    thm_5_mean_Transition  thm_5_std_Gesture  thm_5_std_Transition  \
# 0              27.443073           0.513923              0.982867
# 1              24.889104           0.895062              0.264488
# 2              24.870243           0.114652              0.693859
#
#    thm_5_min_Gesture  thm_5_min_Transition  thm_5_max_Gesture  \
# 0          27.721840             26.047148          29.428299
# 1          24.378687             24.181562          28.054575
# 2          24.437956             24.167980          24.858009
#
#    thm_5_max_Transition  thm_5_skew_Gesture  thm_5_skew_Transition  \
# 0             28.815403            0.780503              -0.136290
# 1             25.145569           -0.859372              -1.282659
# 2             26.051331            0.030210               0.685011
#
#    acc_mag_mean_Gesture  acc_mag_mean_Transition  acc_mag_std_Gesture  \
# 0              9.977855                10.077730             0.320601
# 1              9.993138                10.043379             0.900278
# 2             10.189387                 9.922447             0.750752
#
#    acc_mag_std_Transition  acc_mag_min_Gesture  acc_mag_min_Transition  \
# 0                0.370631             9.170917                9.561136
# 1                0.324914             7.160294                9.485942
# 2                0.685781             8.309325                9.007764
#
#    acc_mag_max_Gesture  acc_mag_max_Transition  acc_mag_skew_Gesture  \
# 0            11.067592               11.140053              0.993389
# 1            11.575777               11.359967             -0.550851
# 2            11.418236               12.072645             -0.568246
#
#    acc_mag_skew_Transition  rot_mag_mean_Gesture  rot_mag_mean_Transition  \
# 0                 1.955505              1.000002                 0.999998
# 1                 2.131329              0.999997                 0.999990
# 2                 1.604378              0.999995                 0.999994
#
#    rot_mag_std_Gesture  rot_mag_std_Transition  rot_mag_min_Gesture  \
# 0             0.000017                0.000017             0.999975
# 1             0.000015                0.000013             0.999974
# 2             0.000019                0.000017             0.999965
#
#    rot_mag_min_Transition  rot_mag_max_Gesture  rot_mag_max_Transition  \
# 0                0.999960             1.000032                1.000028
# 1                0.999966             1.000025                1.000022
# 2                0.999968             1.000032                1.000034
#
#    rot_mag_skew_Gesture  rot_mag_skew_Transition  jerk_mean_Gesture  \
# 0              0.164118                 0.020982           0.000941
# 1              0.352029                 0.424091          -0.091381
# 2              0.015226                 0.552284          -0.037628
#
#    jerk_mean_Transition  jerk_std_Gesture  jerk_std_Transition  \
# 0              0.017588          0.498341             0.454179
# 1              0.003790          1.143210             0.503068
# 2              0.028173          1.238615             0.942134
#
#    jerk_min_Gesture  jerk_min_Transition  jerk_max_Gesture  \
# 0         -1.896675            -1.275742          0.775677
# 1         -2.329603            -1.567471          1.677727
# 2         -2.902877            -2.750848          2.458852
#
#    jerk_max_Transition  jerk_skew_Gesture  jerk_skew_Transition  \
# 0             1.242384          -1.641391              0.070289
# 1             1.346165          -0.775943              0.051420
# 2             1.693660          -0.024235             -0.751645
#
#    thm_grad_1_2_mean_Gesture  thm_grad_1_2_mean_Transition  \
# 0                  -2.188258                      0.654901
# 1                   0.256710                      1.285243
# 2                   0.246057                      0.037041
#
#    thm_grad_1_2_std_Gesture  thm_grad_1_2_std_Transition  \
# 0                  0.282866                     2.965536
# 1                  0.858768                     1.383707
# 2                  0.101063                     0.312214
#
#    thm_grad_1_2_min_Gesture  thm_grad_1_2_min_Transition  \
# 0                 -2.649433                    -2.878344
# 1                 -0.368416                    -0.417637
# 2                 -0.001427                    -0.541615
#
#    thm_grad_1_2_max_Gesture  thm_grad_1_2_max_Transition  \
# 0                 -1.557152                     4.046410
# 1                  3.846796                     3.829411
# 2                  0.447063                     0.652330
#
#    thm_grad_1_2_skew_Gesture  thm_grad_1_2_skew_Transition  \
# 0                   0.623726                     -0.157089
# 1                   3.315974                     -0.139404
# 2                  -0.310067                     -0.160022
#
#    thm_grad_2_3_mean_Gesture  thm_grad_2_3_mean_Transition  \
# 0                   1.644328                      0.164465
# 1                   1.680335                     -0.616083
# 2                  -0.679296                     -0.324321
#
#    thm_grad_2_3_std_Gesture  thm_grad_2_3_std_Transition  \
# 0                  0.380689                     1.835484
# 1                  1.018859                     0.966461
# 2                  0.191245                     0.550552
#
#    thm_grad_2_3_min_Gesture  thm_grad_2_3_min_Transition  \
# 0                  1.034723                    -2.266716
# 1                 -1.734512                    -4.542854
# 2                 -1.040720                    -0.954321
#
#    thm_grad_2_3_max_Gesture  thm_grad_2_3_max_Transition  \
# 0                  2.397999                     2.614817
# 1                  2.870394                     0.281979
# 2                 -0.341410                     0.743389
#
#    thm_grad_2_3_skew_Gesture  thm_grad_2_3_skew_Transition  \
# 0                   0.170443                      0.189357
# 1                  -2.065082                     -2.777034
# 2                  -0.006536                      0.518358
#
#    thm_grad_3_4_mean_Gesture  thm_grad_3_4_mean_Transition  \
# 0                   0.038283                     -1.420039
# 1                  -0.916384                     -1.703415
# 2                   0.079973                     -0.192837
#
#    thm_grad_3_4_std_Gesture  thm_grad_3_4_std_Transition  \
# 0                  0.137916                     1.993306
# 1                  1.089324                     3.108427
# 2                  0.112028                     0.545821
#
#    thm_grad_3_4_min_Gesture  thm_grad_3_4_min_Transition  \
# 0                 -0.325338                    -3.726547
# 1                 -4.048893                    -4.839048
# 2                 -0.140873                    -1.216579
#
#    thm_grad_3_4_max_Gesture  thm_grad_3_4_max_Transition  \
# 0                  0.280298                     1.293926
# 1                  0.461081                     2.746029
# 2                  0.272602                     0.499920
#
#    thm_grad_3_4_skew_Gesture  thm_grad_3_4_skew_Transition  \
# 0                  -0.710368                     -0.079750
# 1                  -1.252089                      0.181023
# 2                  -0.297100                     -0.109936
#
#    thm_grad_4_5_mean_Gesture  thm_grad_4_5_mean_Transition  \
# 0                   0.719338                      1.861966
# 1                   4.436330                      4.904119
# 2                   0.036643                      0.407354
#
#    thm_grad_4_5_std_Gesture  thm_grad_4_5_std_Transition  \
# 0                  0.612231                     1.303043
# 1                  0.630283                     0.793452
# 2                  0.243243                     0.287609
#
#    thm_grad_4_5_min_Gesture  thm_grad_4_5_min_Transition  \
# 0                 -0.387695                     0.183680
# 1                  3.409300                     4.011812
# 2                 -0.330923                    -0.020517
#
#    thm_grad_4_5_max_Gesture  thm_grad_4_5_max_Transition  \
# 0                  1.624285                     3.706160
# 1                  5.667048                     5.865318
# 2                  0.476324                     1.246277
#
#    thm_grad_4_5_skew_Gesture  thm_grad_4_5_skew_Transition  \
# 0                  -0.521508                      0.141870
# 1                   0.313367                      0.150111
# 2                   0.279415                      1.506933
#
#    tof_invalid_pct_mean_Gesture  tof_invalid_pct_mean_Transition  \
# 0                      0.371680                         0.479750
# 1                      0.269508                         0.636518
# 2                      0.887292                         0.551495
#
#    tof_invalid_pct_std_Gesture  tof_invalid_pct_std_Transition  \
# 0                     0.047432                        0.167239
# 1                     0.095645                        0.274283
# 2                     0.079218                        0.333370
#
#    tof_invalid_pct_min_Gesture  tof_invalid_pct_min_Transition  \
# 0                     0.281250                        0.231250
# 1                     0.203125                        0.309375
# 2                     0.768750                        0.150000
#
#    tof_invalid_pct_max_Gesture  tof_invalid_pct_max_Transition  \
# 0                     0.453125                        0.684375
# 1                     0.768750                        0.928125
# 2                     0.975000                        0.915625
#
#    tof_invalid_pct_skew_Gesture  tof_invalid_pct_skew_Transition  \
# 0                     -0.256594                         0.091825
# 1                      4.723081                        -0.192509
# 2                     -0.328373                        -0.071184
#
#    tof_pca_0_mean_Gesture  tof_pca_0_mean_Transition  tof_pca_0_std_Gesture  \
# 0              -22.607758                 543.027036             241.834416
# 1              962.369093                 183.828937             155.828401
# 2             -386.201317                 246.614082             309.114367
#
#    tof_pca_0_std_Transition  tof_pca_0_min_Gesture  tof_pca_0_min_Transition  \
# 0                323.473134            -384.958630                 53.941335
# 1                510.548260             297.661368               -470.607221
# 2                657.013661            -714.557738               -524.018765
#
#    tof_pca_0_max_Gesture  tof_pca_0_max_Transition  tof_pca_0_skew_Gesture  \
# 0             436.718270               1200.546304                0.560053
# 1            1245.514052                802.297193               -2.245366
# 2              70.079935               1426.695253                0.354448
#
#    tof_pca_0_skew_Transition  tof_pca_1_mean_Gesture  \
# 0                  -0.046242               52.458076
# 1                   0.035907             -231.601257
# 2                   0.304640             -526.798589
#
#    tof_pca_1_mean_Transition  tof_pca_1_std_Gesture  tof_pca_1_std_Transition  \
# 0                 162.377648              60.708098                211.132096
# 1                -185.054577             135.856006                433.613544
# 2                -302.768670             312.123331                506.363391
#
#    tof_pca_1_min_Gesture  tof_pca_1_min_Transition  tof_pca_1_max_Gesture  \
# 0             -79.900672               -153.878832             153.915369
# 1            -478.276002               -927.495540              25.564866
# 2            -967.185402              -1155.603005            -160.581616
#
#    tof_pca_1_max_Transition  tof_pca_1_skew_Gesture  \
# 0                430.489704               -0.450427
# 1                303.060156               -0.046413
# 2                442.584322               -0.178211
#
#    tof_pca_1_skew_Transition  tof_pca_2_mean_Gesture  \
# 0                   0.045137             -144.839784
# 1                  -0.180489              237.804746
# 2                   0.081631              224.246225
#
#    tof_pca_2_mean_Transition  tof_pca_2_std_Gesture  tof_pca_2_std_Transition  \
# 0                 315.982696              74.499527                461.571761
# 1                 371.908914              81.717635                138.408061
# 2                 199.922423             168.782378                187.448466
#
#    tof_pca_2_min_Gesture  tof_pca_2_min_Transition  tof_pca_2_max_Gesture  \
# 0            -249.215313               -217.515079              24.568420
# 1             159.760266                 49.852018             648.391508
# 2              14.959682               -234.387395             487.573283
#
#    tof_pca_2_max_Transition  tof_pca_2_skew_Gesture  \
# 0                861.657139                0.835621
# 1                577.209804                4.116503
# 2                562.834494                0.169694
#
#    tof_pca_2_skew_Transition  tof_pca_3_mean_Gesture  \
# 0                   0.050150               99.929143
# 1                  -0.160388             -292.886214
# 2                  -0.475579              364.715763
#
#    tof_pca_3_mean_Transition  tof_pca_3_std_Gesture  tof_pca_3_std_Transition  \
# 0                -147.750075              49.515569                255.271966
# 1                -238.515622              94.946252                137.854018
# 2                 268.958663             244.660771                234.408394
#
#    tof_pca_3_min_Gesture  tof_pca_3_min_Transition  tof_pca_3_max_Gesture  \
# 0              10.248764               -460.565167             198.986008
# 1            -593.972239               -583.730319             -98.357729
# 2              46.501682               -327.304973             705.686603
#
#    tof_pca_3_max_Transition  tof_pca_3_skew_Gesture  \
# 0                145.085479               -0.135408
# 1                 98.661902               -0.959556
# 2                521.115531               -0.021498
#
#    tof_pca_3_skew_Transition  tof_pca_4_mean_Gesture  \
# 0                  -0.046852              236.865309
# 1                  -0.009018             -193.017296
# 2                  -1.023586             -170.624795
#
#    tof_pca_4_mean_Transition  tof_pca_4_std_Gesture  tof_pca_4_std_Transition  \
# 0                 200.322996              54.023843                 70.797483
# 1                  15.207375              79.185715                145.420677
# 2                  24.254217              61.778892                276.568305
#
#    tof_pca_4_min_Gesture  tof_pca_4_min_Transition  tof_pca_4_max_Gesture  \
# 0             128.589022                 12.469457             306.145225
# 1            -307.384447               -182.255156              76.576567
# 2            -273.038502               -388.404070             -91.879904
#
#    tof_pca_4_max_Transition  tof_pca_4_skew_Gesture  \
# 0                283.695181               -0.805197
# 1                189.779336                2.056715
# 2                384.009092                0.019431
#
#    tof_pca_4_skew_Transition  tof_pca_5_mean_Gesture  \
# 0                  -0.780005              -98.249872
# 1                  -0.275894              112.318938
# 2                   0.267777             -177.697891
#
#    tof_pca_5_mean_Transition  tof_pca_5_std_Gesture  tof_pca_5_std_Transition  \
# 0                -150.788040              74.969710                217.958795
# 1                  64.094566              68.660825                103.992361
# 2                 -37.070773              55.263405                182.298385
#
#    tof_pca_5_min_Gesture  tof_pca_5_min_Transition  tof_pca_5_max_Gesture  \
# 0            -234.949524               -471.251800              70.733944
# 1            -167.533609               -218.902711             217.304143
# 2            -275.051420               -292.181855            -112.228152
#
#    tof_pca_5_max_Transition  tof_pca_5_skew_Gesture  \
# 0                264.743052                0.708392
# 1                339.792856               -1.989233
# 2                249.594640               -0.177806
#
#    tof_pca_5_skew_Transition  tof_pca_6_mean_Gesture  \
# 0                   0.373321              -32.102086
# 1                  -0.058425             -137.281659
# 2                   0.461914             -189.039620
#
#    tof_pca_6_mean_Transition  tof_pca_6_std_Gesture  tof_pca_6_std_Transition  \
# 0                  10.531423              64.981824                 75.152808
# 1                   6.725439              66.178269                 45.827349
# 2                -122.635751              94.796652                187.402940
#
#    tof_pca_6_min_Gesture  tof_pca_6_min_Transition  tof_pca_6_max_Gesture  \
# 0            -215.542898               -198.907051              82.282031
# 1            -244.018094               -147.436902              81.995597
# 2            -376.110181               -360.211048             -48.224443
#
#    tof_pca_6_max_Transition  tof_pca_6_skew_Gesture  \
# 0                179.908747               -1.236574
# 1                130.567031                1.026228
# 2                270.170687               -0.460681
#
#    tof_pca_6_skew_Transition  tof_pca_7_mean_Gesture  \
# 0                  -0.401348               -6.357957
# 1                  -0.143645               13.404640
# 2                   0.673649              101.306468
#
#    tof_pca_7_mean_Transition  tof_pca_7_std_Gesture  tof_pca_7_std_Transition  \
# 0                 -77.120343              46.664830                 97.363443
# 1                  -8.424366              78.238608                 99.656513
# 2                 157.300616              75.610200                137.620268
#
#    tof_pca_7_min_Gesture  tof_pca_7_min_Transition  tof_pca_7_max_Gesture  \
# 0            -120.826869               -377.375667              74.373146
# 1            -282.182930               -359.071366             218.451954
# 2             -84.982882               -290.506158             172.811201
#
#    tof_pca_7_max_Transition  tof_pca_7_skew_Gesture  \
# 0                 57.334558               -0.233751
# 1                113.687761               -1.105740
# 2                368.919687               -1.005489
#
#    tof_pca_7_skew_Transition  tof_pca_8_mean_Gesture  \
# 0                  -1.615970              -55.193642
# 1                  -2.500468             -104.822739
# 2                  -1.645940              142.088005
#
#    tof_pca_8_mean_Transition  tof_pca_8_std_Gesture  tof_pca_8_std_Transition  \
# 0                 -19.757805              97.921693                 64.837690
# 1                  -5.642818              78.536712                180.001712
# 2                  72.737102              56.772362                164.109345
#
#    tof_pca_8_min_Gesture  tof_pca_8_min_Transition  tof_pca_8_max_Gesture  \
# 0            -204.706496               -186.575340             117.340559
# 1            -366.934511               -362.977023             -28.428955
# 2              27.482126               -267.615522             295.615107
#
#    tof_pca_8_max_Transition  tof_pca_8_skew_Gesture  \
# 0                106.709203                0.450027
# 1                230.174779               -1.937548
# 2                274.991692                0.338005
#
#    tof_pca_8_skew_Transition  tof_pca_9_mean_Gesture  \
# 0                  -0.171208              -47.608941
# 1                  -0.177006              -81.096235
# 2                  -0.830583              -75.708389
#
#    tof_pca_9_mean_Transition  tof_pca_9_std_Gesture  tof_pca_9_std_Transition  \
# 0                -121.939040              99.625825                 50.821000
# 1                -143.535153              65.276093                 59.719988
# 2                -109.362959              78.443540                111.799101
#
#    tof_pca_9_min_Gesture  tof_pca_9_min_Transition  tof_pca_9_max_Gesture  \
# 0            -124.599026               -250.524568             219.235456
# 1            -325.369799               -353.583140              38.881442
# 2            -201.581575               -340.622004             124.489261
#
#    tof_pca_9_max_Transition  tof_pca_9_skew_Gesture  \
# 0                -30.747318                1.715353
# 1                110.488030               -1.484493
# 2                203.674609                0.684230
#
#    tof_pca_9_skew_Transition  acc_mag_mean_Gesture_div_age  \
# 0                  -1.073033                      0.831488
# 1                   1.052192                      0.416381
# 2                   1.299255                      0.849116
#
#    acc_mag_mean_Gesture_mul_age  acc_mag_mean_Gesture_div_height_cm  \
# 0                    119.734261                            0.061214
# 1                    239.835322                            0.057764
# 2                    122.272644                            0.064901
#
#    acc_mag_mean_Gesture_mul_height_cm  \
# 0                         1626.390378
# 1                         1728.812944
# 2                         1599.733758
#
#    acc_mag_mean_Gesture_div_shoulder_to_wrist_cm  \
# 0                                       0.191882
# 1                                       0.203942
# 2                                       0.231577
#
#    acc_mag_mean_Gesture_mul_shoulder_to_wrist_cm  acc_mag_std_Gesture_div_age  \
# 0                                     518.848464                     0.026717
# 1                                     489.663782                     0.037512
# 2                                     448.333028                     0.062563
#
#    acc_mag_std_Gesture_mul_age  acc_mag_std_Gesture_div_height_cm  \
# 0                     3.847215                           0.001967
# 1                    21.606667                           0.005204
# 2                     9.009029                           0.004782
#
#    acc_mag_std_Gesture_mul_height_cm  \
# 0                          52.258001
# 1                         155.748057
# 2                         117.868131
#
#    acc_mag_std_Gesture_div_shoulder_to_wrist_cm  \
# 0                                      0.006165
# 1                                      0.018373
# 2                                      0.017063
#
#    acc_mag_std_Gesture_mul_shoulder_to_wrist_cm  jerk_mean_Gesture_div_age  \
# 0                                     16.671264                   0.000078
# 1                                     44.113611                  -0.003808
# 2                                     33.033107                  -0.003136
#
#    jerk_mean_Gesture_mul_age  jerk_mean_Gesture_div_height_cm  \
# 0                   0.011290                         0.000006
# 1                  -2.193132                        -0.000528
# 2                  -0.451530                        -0.000240
#
#    jerk_mean_Gesture_mul_height_cm  \
# 0                         0.153358
# 1                       -15.808827
# 2                        -5.907524
#
#    jerk_mean_Gesture_div_shoulder_to_wrist_cm  \
# 0                                    0.000018
# 1                                   -0.001865
# 2                                   -0.000855
#
#    jerk_mean_Gesture_mul_shoulder_to_wrist_cm  jerk_std_Gesture_div_age  \
# 0                                    0.048924                  0.041528
# 1                                   -4.477645                  0.047634
# 2                                   -1.655612                  0.103218
#
#    jerk_std_Gesture_mul_age  jerk_std_Gesture_div_height_cm  \
# 0                  5.980093                        0.003057
# 1                 27.437037                        0.006608
# 2                 14.863381                        0.007889
#
#    jerk_std_Gesture_mul_height_cm  jerk_std_Gesture_div_shoulder_to_wrist_cm  \
# 0                       81.229598                                   0.009583
# 1                      197.775309                                   0.023331
# 2                      194.462564                                   0.028150
#
#    jerk_std_Gesture_mul_shoulder_to_wrist_cm  tof_pca_0_mean_Gesture_div_age  \
# 0                                  25.913737                       -1.883980
# 1                                  56.017284                       40.098711
# 2                                  54.499062                      -32.183440
#
#    tof_pca_0_mean_Gesture_mul_age  tof_pca_0_mean_Gesture_div_height_cm  \
# 0                     -271.293096                             -0.138698
# 1                    23096.858235                              5.562827
# 2                    -4634.415799                             -2.459881
#
#    tof_pca_0_mean_Gesture_mul_height_cm  \
# 0                          -3685.064553
# 1                         166489.853114
# 2                         -60633.606706
#
#    tof_pca_0_mean_Gesture_div_shoulder_to_wrist_cm  \
# 0                                        -0.434765
# 1                                        19.640185
# 2                                        -8.777302
#
#    tof_pca_0_mean_Gesture_mul_shoulder_to_wrist_cm  \
# 0                                     -1175.603416
# 1                                     47156.085564
# 2                                    -16992.857930
#
#    tof_invalid_pct_mean_Gesture_div_age  tof_invalid_pct_mean_Gesture_mul_age  \
# 0                              0.030973                              4.460156
# 1                              0.011229                              6.468182
# 2                              0.073941                             10.647500
#
#    tof_invalid_pct_mean_Gesture_div_height_cm  \
# 0                                    0.002280
# 1                                    0.001558
# 2                                    0.005652
#
#    tof_invalid_pct_mean_Gesture_mul_height_cm  \
# 0                                   60.583789
# 1                                   46.624811
# 2                                  139.304792
#
#    tof_invalid_pct_mean_Gesture_div_shoulder_to_wrist_cm  \
# 0                                           0.007148
# 1                                           0.005500
# 2                                           0.020166
#
#    tof_invalid_pct_mean_Gesture_mul_shoulder_to_wrist_cm  gesture_encoded
# 0                                          19.327344                    0
# 1                                          13.205871                    1
# 2                                          39.040833                    0

# %%
# Save to feather format for future loads
features_df.to_feather("outputs/features_4n.fea")

# %%
# --- Model Parameters ---
params = {
    'iterations': 1000, 'learning_rate': 0.05, 'depth': 6,
    'loss_function': 'MultiClass', 'eval_metric': 'MultiClass',
    'random_seed': SEED, 'verbose': 0
}

# --- Prepare data for CV ---
X = features_df.drop(columns=['sequence_id', 'subject', 'gesture', 'gesture_encoded'])
y = features_df['gesture_encoded']
groups = features_df['subject']

# %% [markdown]
# ## Training Run for Feature Wave 4n (4 + Sex and Handedness Features)

# %%
# Setup training run and prep data
FEATURE_WAVE = "Wave 4n - Fixed"
MODEL_NAME = "Catboost"
EXPERIMENT_NAME = f"{FEATURE_WAVE}-{MODEL_NAME}-CPU"
N_SPLITS = 5

# %%
# Train and evaluate.
fold_scores = []
cv = StratifiedGroupKFold(n_splits=N_SPLITS, shuffle=True, random_state=SEED)
for fold, (train_idx, val_idx) in enumerate(cv.split(X, y, groups)):
    print(f"--- Fold {fold+1}/{N_SPLITS} ---")
    
    X_train, y_train = X.iloc[train_idx], y.iloc[train_idx]
    X_val, y_val = X.iloc[val_idx], y.iloc[val_idx]
    
    model = cat.CatBoostClassifier(**params)
    model.fit(X_train, y_train, eval_set=[(X_val, y_val)], early_stopping_rounds=100)
    
    # Predict on validation set
    val_preds_proba = model.predict_proba(X_val)
    
    # Evaluate fold performance using the official metric
    fold_score = average_f1_score(y_val, val_preds_proba)
    fold_scores.append(fold_score)
    print(f"Fold {fold+1} Competition F1 Score: {fold_score:.5f}")

# --- Final Score and Logging ---
mean_cv_score = np.mean(fold_scores)
print(f"\n--- CV Summary for {MODEL_NAME} ---")
print(f"Mean Competition F1 Score: {mean_cv_score:.5f}")
print(f"Std Dev: {np.std(fold_scores):.5f}\n")

tracker.log_experiment(
    experiment_name=EXPERIMENT_NAME, model_name=MODEL_NAME, feature_wave=FEATURE_WAVE,
    cv_score=mean_cv_score, params=params,
    notes="Evaluating Wave-4n baseline - Wave 3a+interaction features + flagged changes"
)
# Out:
# --- Fold 1/5 ---
# Fold 1 Competition F1 Score: 0.83423
# --- Fold 2/5 ---
# Fold 2 Competition F1 Score: 0.78641
# --- Fold 3/5 ---
# Fold 3 Competition F1 Score: 0.80067
# --- Fold 4/5 ---
# Fold 4 Competition F1 Score: 0.78675
# --- Fold 5/5 ---
# Fold 5 Competition F1 Score: 0.80138
#
# --- CV Summary for Catboost ---
# Mean Competition F1 Score: 0.80189
# Std Dev: 0.01741
#
# Experiment 'Wave 4n - Fixed-Catboost-CPU' logged to /home/bac/code/kaggle/kaggle-cmi-detect-behavior/experiment_log.csv
# wandb: Currently logged in as: b-a-chaudhry (b-a-chaudhry-) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: WARNING Using a boolean value for 'reinit' is deprecated. Use 'return_previous' or 'finish_previous' instead.
# Tracking run with wandb version 0.21.0
# Run data is saved locally in <code>/home/bac/code/kaggle/kaggle-cmi-detect-behavior/notebooks/wandb/run-20250714_175734-fpls6y3z</code>
# Syncing run <strong><a href='https://wandb.ai/b-a-chaudhry-/kaggle-cmi-detect-behavior/runs/fpls6y3z' target="_blank">Wave 4n - Fixed-Catboost-CPU</a></strong> to <a href='https://wandb.ai/b-a-chaudhry-/kaggle-cmi-detect-behavior' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/b-a-chaudhry-/kaggle-cmi-detect-behavior' target="_blank">https://wandb.ai/b-a-chaudhry-/kaggle-cmi-detect-behavior</a>
#  View run at <a href='https://wandb.ai/b-a-chaudhry-/kaggle-cmi-detect-behavior/runs/fpls6y3z' target="_blank">https://wandb.ai/b-a-chaudhry-/kaggle-cmi-detect-behavior/runs/fpls6y3z</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>cv_score</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>cv_score</td><td>0.80189</td></tr><tr><td>feature_wave</td><td>Wave 4n - Fixed</td></tr><tr><td>model_name</td><td>Catboost</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">Wave 4n - Fixed-Catboost-CPU</strong> at: <a href='https://wandb.ai/b-a-chaudhry-/kaggle-cmi-detect-behavior/runs/fpls6y3z' target="_blank">https://wandb.ai/b-a-chaudhry-/kaggle-cmi-detect-behavior/runs/fpls6y3z</a><br> View project at: <a href='https://wandb.ai/b-a-chaudhry-/kaggle-cmi-detect-behavior' target="_blank">https://wandb.ai/b-a-chaudhry-/kaggle-cmi-detect-behavior</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250714_175734-fpls6y3z/logs</code>
# Experiment 'Wave 4n - Fixed-Catboost-CPU' logged to W&B

# %% [markdown]
# ## Feature and Permutation Importance for Pruning

# %%
# Training on one representative fold for feature analysis
cv_split = StratifiedGroupKFold(n_splits=5, shuffle=True, random_state=SEED).split(X, y, groups=features_df['sequence_id'])
train_idx, val_idx = next(cv_split)

X_train, y_train = X.iloc[train_idx], y.iloc[train_idx]
X_val, y_val = X.iloc[val_idx], y.iloc[val_idx]

# Train model and get importances
print("Training a single model on fold 0 to analyze feature importance...")
model = get_trained_model(X_train, y_train, X_val, y_val, params)
# Out:
# Training a single model on fold 0 to analyze feature importance...

# %%
feat_importance = plot_feature_importance(model, X.columns)

# %%
# --- Create the scorer function ---
competition_scorer_func = create_competition_scorer(inv_gesture_map, gesture_to_seq_type_map)

# --- Run Permutation Importance on CatBoost ---
# Use needs_proba=False, as we've seen this can be unreliable. Our function handles both cases.
scorer_for_perm_importance = make_scorer(competition_scorer_func, needs_proba=False)

perm_importance_df = calculate_permutation_importance(
    model, 
    X_val, 
    y_val,
    scorer=scorer_for_perm_importance
)
# Out:
# Calculating Permutation Importance...
#
# !!! No features with positive permutation importance were found.

# %% [markdown]
# ## Solving the Permutation Importance Issue With Custom Workarounds

# %% [markdown]
# ### Test to examine Permutation Importance Problem.

# %%
import lightgbm as lgb

# --- 1. Train a LightGBM model on the same data fold ---
print("--- Diagnostic Step: Training a LightGBM model ---")
lgbm_params = {
    'objective': 'multiclass',
    'num_class': y.nunique(),
    'metric': 'multi_logloss',
    'n_estimators': 1000,
    'learning_rate': 0.05,
    'feature_fraction': 0.8,
    'bagging_fraction': 0.8,
    'bagging_freq': 1,
    'lambda_l1': 0.1,
    'lambda_l2': 0.1,
    'num_leaves': 31,
    'verbose': -1,
    'n_jobs': -1,
    'seed': SEED
}

lgbm_model = lgb.LGBMClassifier(**lgbm_params)
lgbm_model.fit(X_train, y_train,
             eval_set=[(X_val, y_val)],
             callbacks=[lgb.early_stopping(100, verbose=False)])

print("LightGBM model trained.")

# --- 2. Create the scorer (using the same factory) ---
# This ensures we are using the identical scoring logic
competition_scorer_func = create_competition_scorer(inv_gesture_map, gesture_to_seq_type_map)
final_scorer = make_scorer(competition_scorer_func, needs_proba=True)

# --- 3. Run Permutation Importance on the LightGBM model ---
print("\n--- Running Permutation Importance on LightGBM ---")

# We are using the exact same function and scorer as before
perm_importance_lgbm_df = calculate_permutation_importance(
    lgbm_model,
    X_val,
    y_val,
    scorer=final_scorer
)
# Out:
# --- Diagnostic Step: Training a LightGBM model ---
# LightGBM model trained.
#
# --- Running Permutation Importance on LightGBM ---
# Calculating Permutation Importance...
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 11  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 11  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  5]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  8 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  8 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  1 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  5]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  5]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  5]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  5]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 13  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 13  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# ...
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  5]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  5]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  5]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  5]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  5]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
# DEBUG: Scorer received y_pred of type: <class 'numpy.ndarray'>, shape: (1631,)
# DEBUG: First 5 elements of 1D y_pred: [ 0  3  7 10  4]
#
# Top 10 Permutation Importances:
#                      feature  importance_mean  importance_std
# 87       thm_2_mean_Gesture         0.009938        0.001596
# 29        acc_z_std_Gesture         0.006606        0.004008
# 221  tof_pca_2_mean_Gesture         0.006307        0.001920
# 9         acc_x_std_Gesture         0.006180        0.002693
# 19        acc_y_std_Gesture         0.006005        0.005101
# 83        thm_1_max_Gesture         0.004951        0.001465
# 209   tof_pca_0_min_Gesture         0.004098        0.001727
# 23        acc_y_max_Gesture         0.003964        0.001929
# 20     acc_y_std_Transition         0.003137        0.001519
# 35       acc_z_skew_Gesture         0.002634        0.002387

# %% [markdown]
# ### Bypassing `sklearn.inspection.permutation_importance`

# %%
# Get the most important feature from the CatBoost Feature Importance Plot
top_feature = feat_importance['feature'].iloc[0]

# Baseline predictions on the original unshuffled data
baseline_predictions = model.predict(X_val)

# Copy of validation to shuffle
X_val_shuffled = X_val.copy()

# Shuffle only the single most important column and assign back
shuffled_column = X_val_shuffled[top_feature].sample(frac=1, random_state=SEED).values
X_val_shuffled[top_feature] = shuffled_column

# Get new predictions with the shuffled column
shuffled_predictions = model.predict(X_val_shuffled)

# Compare the predictions
are_predictions_identical = np.array_equal(baseline_predictions, shuffled_predictions)

print("Results")

if are_predictions_identical:
    print("!!! TEST FAILED: The model's predictions DID NOT CHANGE after shuffling the most important feature.")
    print("This confirms the root cause: The CatBoost model object is invariant to this shuffling.")
    print("This is not a scorer issue, but an issue with the model's prediction behavior in this context.")
else:
    print(">>> TEST PASSED: The model's predictions CHANGED after shuffling.")
    print("This means the permutation is having an effect, and the issue lies elsewhere.")
    
# Check the scores to see the impact
scorer_func = create_competition_scorer(inv_gesture_map, gesture_to_seq_type_map)
baseline_score = scorer_func(y_val, model.predict_proba(X_val))
shuffled_score = scorer_func(y_val, model.predict_proba(X_val_shuffled))

print(f"\nBaseline Score on original data: {baseline_score:.5f}")
print(f"Score on data with one shuffled column: {shuffled_score:.5f}")
print(f"Score Difference (Importance): {baseline_score - shuffled_score:.5f}")
# Out:
# Results
# >>> TEST PASSED: The model's predictions CHANGED after shuffling.
# This means the permutation is having an effect, and the issue lies elsewhere.
#
# Baseline Score on original data: 0.82151
# Score on data with one shuffled column: 0.81193
# Score Difference (Importance): 0.00958

# %% [markdown]
# ### SOLUTION: Custom Function for Permutation Importance Calculations

# %% [markdown]
# The manual test proved the following:
#
# - The CatBoost Model is Working: Manually shuffling a column while keeping the data as a pandas DataFrame and passing it to model.predict() changed the predictions, and the score dropped. This is correct behavior.
#
# - The Scorer is Working: THe custom scorer function correctly identified the drop in performance when the predictions changed.
#
# - The Root Cause: The only difference between the successful manual test and the failing automated function is what happens to the data inside the permutation_importance function. Internally, permutation_importance converts the input pandas DataFrame (X_val) into a NumPy array to perform its shuffling operations. This conversion strips the feature names.
#
# - The CatBoost model was trained on a DataFrame with named features. When it is later fed a nameless NumPy array for prediction, it appears to behave differently and, in this specific context, becomes insensitive to the shuffling of a single column, causing it to return the same predictions and thus a zero importance score.
#
# Replacing the packaged function with a custom function.

# %%
def custom_permutation_importance(model, X_val, y_val, scorer, top_n=200, n_repeats=5):
    """
    A custom implementation of permutation importance that operates directly on
    pandas DataFrames to avoid issues with scikit-learn's internal type casting.
    """
    print("Calculating Permutation Importance using custom implementation...")
    
    # Calculate baseline score on the original data
    baseline_predictions = model.predict_proba(X_val)
    baseline_score = scorer(y_val, baseline_predictions)
    print(f"Baseline score: {baseline_score:.5f}")
    
    importances = []
    
    for col in X_val.columns:
        original_col = X_val[col].copy()
        col_scores = []
        
        for r in range(n_repeats):
            # Shuffle a single column
            X_val[col] = np.random.RandomState(r).permutation(original_col)
            
            # Get new score
            permuted_predictions = model.predict_proba(X_val)
            permuted_score = scorer(y_val, permuted_predictions)
            col_scores.append(permuted_score)
            
        # Restore the original column
        X_val[col] = original_col
        
        # Calculate importance as the drop in score
        importance = baseline_score - np.mean(col_scores)
        importances.append(importance)
        
    # Create and Plot the Results 
    perm_importance_df = pd.DataFrame({
        'feature': X_val.columns,
        'importance_mean': importances,
    }).sort_values('importance_mean', ascending=False)
    
    positive_importance_df = perm_importance_df[perm_importance_df['importance_mean'] > 0].head(top_n)
    
    if positive_importance_df.empty:
        print("\n No features with positive permutation importance were found!!!")
        return perm_importance_df
    
    print("\n Top 10 permutation Importances:\n", positive_importance_df.head(10))
    
    plt.figure(figsize=(8, max(10, top_n / 4)))
    plt.barh(
        positive_importance_df['feature'],
        positive_importance_df['importance_mean']
    )
    plt.title(f'Top {top_n} Features (Custom Permutation Importance)')
    plt.xlabel('Importance (Decrease in F1 Score)')
    plt.gca().invert_yaxis()
    plt.tight_layout()
    plt.show()
    
    return perm_importance_df

# %%
# Recreate scorer function
competition_scorer_func = create_competition_scorer(inv_gesture_map, gesture_to_seq_type_map)

# Run custom permutation importance on CatBoost
perm_importance_df = custom_permutation_importance(
    model,
    X_val,
    y_val,
    scorer=competition_scorer_func
)
# Out:
# Calculating Permutation Importance using custom implementation...
# Baseline score: 0.81491
#
#  Top 10 permutation Importances:
#                      feature  importance_mean
# 29        acc_z_std_Gesture         0.011634
# 19        acc_y_std_Gesture         0.008877
# 9         acc_x_std_Gesture         0.004547
# 93        thm_2_max_Gesture         0.003645
# 87       thm_2_mean_Gesture         0.003379
# 231   tof_pca_2_min_Gesture         0.002144
# 63        rot_y_max_Gesture         0.002054
# 297  tof_pca_9_mean_Gesture         0.001748
# 227  tof_pca_2_mean_Gesture         0.001733
# 64     rot_y_max_Transition         0.001675

# %%
#display_all(feat_importance)

# %%
feat_importance.to_csv("outputs/feature_importance_W4n.csv", index=False)
perm_importance_df.to_csv("outputs/permutation_importance_W4n.csv", index=False)

# %% [markdown]
# **Analysis of Final Permutation Importance Results** - (revised)
#
# 1. Permutation Importance: The Ground Truth
#
#     - The Unquestionable Champions: The top features are overwhelmingly _std and _max/_min aggregations from the Gesture phase. Specifically, acc_z_std_Gesture, acc_y_std_Gesture, and acc_x_std_Gesture are in a class of their own. This tells us the variability of acceleration during the gesture is the single most powerful predictor.
#
#     - The Supporting Cast: Features from ToF PCA (tof_pca_2_min_Gesture) and rotation (rot_y_max/min_Gesture) are also highly valuable, confirming the success of our earlier feature engineering waves.
#
#     - The Demotion of Interaction Features: Many of the demographic interaction features we created (_div_age, _mul_height_cm) have very low positive importance. They contribute, but only marginally.
#
#     - The Dead Weight: Crucially, the permutation importance list shows a large number of features with zero or negative importance. This includes the raw demographic features (sex, handedness, age, etc.) and many of the more complex interaction terms. These features are either useless or actively harming the model's performance by adding noise.
#
# 2. Built-in Importance vs. Permutation Importance
#
#     - Built-in Importance Can Be Misleading: The built-in method gave high ranks to features like thm_2_max_Gesture. While useful, permutation importance shows it has less direct impact on the final F1 score than the top IMU features.
#
#     - Permutation Correctly Identifies Useless Features: The built-in method gives some small importance to almost every feature, as it might be used for a split somewhere in a tree. Permutation importance is ruthless and correctly identifies that the raw demographic columns provide no value to the final score, as their signal is better captured elsewhere.

# %% [markdown]
# ## API Simulation Test (if necessary)
